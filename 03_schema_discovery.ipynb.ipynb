# %%
# Schema inference and documentation
circuits_df = (
    spark.read
    .option("header", True)
    .csv(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/circuits.csv"
    )
)

circuits_df.printSchema()
display(circuits_df.limit(5))


constructors_df = (
    spark.read
    .option("multiline", True)
    .json(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/constructors.json"
    )
)

constructors_df.printSchema()
display(constructors_df.limit(5))

drivers_df = (
    spark.read
    .option("multiline", True)
    .json(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/drivers.json"
    )
)

drivers_df.printSchema()
display(drivers_df.limit(5))

results_df = (
    spark.read
    .option("multiline", True)
    .json(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/results/results_2025.json"
    )
)

results_df.printSchema()
display(results_df.limit(5))

races_df = (
    spark.read
    .option("header", True)
    .csv(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/races.csv"
    )
)

races_df.printSchema()
display(races_df.limit(5))

sprints_df = (
    spark.read
    .option("multiline", True)
    .json(
        "abfss://raw@devstorageaccountpc01.dfs.core.windows.net/sprints/sprints_2025.json"
    )
)

sprints_df.printSchema()
display(sprints_df.limit(5))
