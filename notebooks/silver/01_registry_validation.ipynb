# %%
import sys

# Add project root to path
sys.path.insert(0, "/Workspace/Users/aman.kumar5@celebaltech.com/project-f1")

# Remove cached src modules to ensure fresh imports every run
for mod in list(sys.modules.keys()):
    if mod.startswith("src"):
        del sys.modules[mod]

# %%
from src.common.config_loader import get_silver_config
from src.silver.transformation_loader import get_transformation

config = get_silver_config(spark, "drivers")

transform_fn = get_transformation(
    config["transformation_name"]
)

print(transform_fn)

# %%
# %sql
DESCRIBE DETAIL dbw_practice01.bronze.drivers

# %%
df = spark.table("dbw_practice01.bronze.drivers")

result = transform_fn(df)

display(result)
